# %%
import pandas as pd

# %%
holidays = pd.read_csv("energy_holidays.csv")
metadata = pd.read_csv("energy_metadata.csv")
frequency= pd.read_csv("energy_submission_frequency.csv")
train = pd.read_csv("energy_train.csv")
#weather = pandas.read_csv("weather.csv")

# %%
train[train.ForecastId==4]
# Out:
#       obs_id  SiteId            Timestamp  ForecastId         Value
# 810  7858028       1  2017-05-20 00:00:00           4  8.735687e+06
# 811   764676       1  2017-05-21 00:00:00           4  8.574455e+06
# 812  3514238       1  2017-05-22 00:00:00           4  7.902457e+06
# 813  1864702       1  2017-05-23 00:00:00           4  7.041917e+06
# 814  5011663       1  2017-05-24 00:00:00           4  5.925648e+06
# 815  1523102       1  2017-05-25 00:00:00           4  6.036873e+06
# 816   483319       1  2017-05-26 00:00:00           4  3.995240e+06
# 817  1655294       1  2017-05-27 00:00:00           4  2.354789e+06
# 818  7221612       1  2017-05-28 00:00:00           4  4.653609e+06
# 819  4150053       1  2017-05-29 00:00:00           4  5.300880e+06
# 820  7834574       1  2017-05-30 00:00:00           4  5.762824e+06
# 821  2576101       1  2017-05-31 00:00:00           4  8.002373e+06
# 822  1672547       1  2017-06-01 00:00:00           4  8.153692e+06
# ...
